# %%
import numpy as np
from scipy import stats
rng=np.random.default_rng()
target1=stats.uniform.rvs(size=100,random_state=rng)
target2=stats.norm.rvs(size=110,random_state=rng)
respone=stats.ks_2samp(sample1,sample2)

# %%
sample1
# Out:
# array([3.17813335e-02, 6.98603579e-01, 7.61841659e-01, 1.06723890e-01,
#        4.14430988e-02, 2.67838080e-01, 4.23988219e-01, 1.80272684e-02,
#        6.95815610e-01, 9.13373243e-04, 6.60197490e-01, 4.30999937e-01,
#        3.49642032e-01, 1.43490618e-01, 6.38981973e-01, 2.03602771e-01,
#        6.44037236e-01, 8.08033580e-01, 3.00669218e-01, 7.64646808e-02,
#        2.51606285e-01, 3.70992127e-01, 9.36147539e-01, 6.62351042e-01,
#        6.09009662e-01, 6.11456928e-01, 2.62771664e-01, 2.96569827e-01,
#        5.23517500e-02, 8.29715342e-01, 2.51567092e-01, 8.03177928e-01,
#        3.10661364e-01, 1.59542631e-01, 6.24315700e-01, 3.01283869e-01,
#        1.43565039e-01, 9.46001247e-01, 8.04887503e-01, 1.47015169e-01,
#        5.44002683e-01, 3.83209728e-02, 9.24156064e-01, 9.72443955e-02,
#        9.77965640e-02, 5.22923744e-01, 5.09381010e-01, 4.73850695e-01,
#        3.93851221e-01, 2.73077270e-01, 1.67319363e-01, 8.44619148e-01,
# ...

# %%
sample2
# Out:
# array([-0.52847798,  1.14081736,  0.29999285, -1.0509269 ,  0.59501016,
#         0.38452652,  0.79874362,  1.55202619, -0.17082271,  0.83942171,
#        -0.87503776, -0.90413238, -2.28580148,  1.16853322,  0.48675537,
#        -1.61273455, -0.23225438, -0.24473223,  0.13070964, -0.66073569,
#        -1.03724241, -0.93388696,  0.41634303, -0.46462129,  1.5336562 ,
#         0.97059626,  0.05539601,  0.35387228,  0.53344814, -0.50693866,
#         0.92062834, -2.01224482,  1.14439537,  1.44579646, -1.37107601,
#         0.11289697,  0.64396748,  1.17849205,  0.39419172,  0.03699533,
#        -0.95515902, -0.20886327, -0.07805562,  1.34836048,  0.69818167,
#         0.76947202, -0.95239728,  0.19713132, -0.5550584 ,  1.04330653,
#        -1.09588273, -0.05101637, -1.80914408, -0.11912814, -0.36517507,
#        -1.35404468,  0.48478907, -0.7865739 , -0.43500909, -2.67670077,
#         0.8891268 ,  0.01336999, -0.17858493,  1.43341798, -2.15305397,
# ...

# %%
round(respone.pvalue,16)
# Out:
# 2.0848e-12

# %%
## Anomly in my dataset
# 1 High null value
2.missing columns
3.outliers
4.categorical;
Gender--><MALE,FEMALE,OTHER

# %%
import pandas as pd

# %%
df=pd.read_csv("/config/workspace/artifact/12012023__132546/data_ingestion/dataset/train.csv")

# %%
drop_column_names=[]
for column_name,missing_percantage in zip((df.isnull().sum()/df.shape[0]).index,(df.isnull().sum()/df.shape[0]).values):
    print(column_name,missing_percantage*100)
    if missing_percantage>0.3:
        drop_column_names.append(column_name)
# Out:
# class 0.0
# aa_000 0.0
# ab_000 77.22970639032816
# ac_000 5.951640759930915
# ad_000 25.606217616580313
# ae_000 4.431778929188256
# af_000 4.431778929188256
# ag_000 1.0535405872193437
# ag_001 1.0535405872193437
# ag_002 1.0535405872193437
# ag_003 1.0535405872193437
# ag_004 1.0535405872193437
# ag_005 1.0535405872193437
# ag_006 1.0535405872193437
# ag_007 1.0535405872193437
# ag_008 1.0535405872193437
# ag_009 1.0535405872193437
# ah_000 1.0984455958549224
# ai_000 1.07426597582038
# aj_000 1.07426597582038
# ak_000 7.844559585492227
# al_000 1.0880829015544042
# am_0 1.07426597582038
# an_000 1.0880829015544042
# ao_000 0.9740932642487047
# ap_000 1.0880829015544042
# aq_000 0.9740932642487047
# ar_000 4.825561312607944
# as_000 1.07426597582038
# at_000 1.07426597582038
# au_000 1.07426597582038
# av_000 4.435233160621762
# ax_000 4.435233160621762
# ay_000 1.0535405872193437
# ay_001 1.0535405872193437
# ay_002 1.0535405872193437
# ay_003 1.0535405872193437
# ...

# %%
drop_column_names
# Out:
# ['ab_000',
#  'bk_000',
#  'bl_000',
#  'bm_000',
#  'bn_000',
#  'bo_000',
#  'bp_000',
#  'bq_000',
#  'br_000',
#  'cr_000']

# %%
null_report=df.isna().sum()/df.shape[0]
null_report[null_report>0.03].index
# Out:
# Index(['ab_000', 'ac_000', 'ad_000', 'ae_000', 'af_000', 'ak_000', 'ar_000',
#        'av_000', 'ax_000', 'bc_000', 'bd_000', 'be_000', 'bf_000', 'bk_000',
#        'bl_000', 'bm_000', 'bn_000', 'bo_000', 'bp_000', 'bq_000', 'br_000',
#        'bx_000', 'bz_000', 'ca_000', 'cc_000', 'ce_000', 'cf_000', 'cg_000',
#        'ch_000', 'cl_000', 'cm_000', 'co_000', 'cp_000', 'cr_000', 'ct_000',
#        'cu_000', 'cv_000', 'cx_000', 'cy_000', 'cz_000', 'da_000', 'db_000',
#        'dc_000', 'dd_000', 'de_000', 'df_000', 'dg_000', 'dh_000', 'di_000',
#        'dj_000', 'dk_000', 'dl_000', 'dm_000', 'do_000', 'dp_000', 'dq_000',
#        'dr_000', 'ds_000', 'dt_000', 'du_000', 'dv_000', 'dx_000', 'dy_000',
#        'dz_000', 'ea_000', 'eb_000', 'ec_00', 'ed_000', 'ef_000', 'eg_000'],
#       dtype='object')

# %%
len(df.iloc[:,[0]].drop("class",axis=1).columns)
# Out:
# 0
